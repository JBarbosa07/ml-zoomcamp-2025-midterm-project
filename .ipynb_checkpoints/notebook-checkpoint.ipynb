# %% [markdown]
# # Midterm Project

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split, KFold
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

from IPython.display import display
from tqdm.auto import tqdm

import xgboost as xgb

# %% [markdown]
# ## Data Preparation
#
# ### Importing Dataset

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#              matchId  blueWins  blueWardsPlaced  blueControlWardsPlaced  \
# 0      KR_7103467251         1               43                       9
# 1      KR_7029911546         1               36                      11
# 2      KR_7077250839         1               33                      11
# 3      KR_7101806500         0               28                       5
# 4      KR_7099122531         1               29                       7
# ...              ...       ...              ...                     ...
# 94350  KR_6995090019         1               81                      10
# 94351  KR_7092903057         1               29                       6
# 94352  KR_7076707982         0               29                       5
# 94353  KR_7077663341         0               36                       8
# 94354  KR_7078465781         0               31                       8
#
#        blueWardsDestroyed  blueControlWardsDestroyed  blueFirstBlood  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94355 entries, 0 to 94354
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   matchId                       94355 non-null  object
#  1   blueWins                      94355 non-null  int64
#  2   blueWardsPlaced               94355 non-null  int64
#  3   blueControlWardsPlaced        94355 non-null  int64
#  4   blueWardsDestroyed            94355 non-null  int64
#  5   blueControlWardsDestroyed     94355 non-null  int64
#  6   blueFirstBlood                94355 non-null  int64
#  7   blueKills                     94355 non-null  int64
#  8   blueDeaths                    94355 non-null  int64
#  9   blueAssists                   94355 non-null  int64
#  10  blueDragons                   94355 non-null  int64
#  11  blueHeralds                   94355 non-null  int64
# ...

# %% [markdown]
# ### Preliminary Cleaning

# %% [markdown]
# Since this project is intended for real-time game prediction purposes we want to only focus on data that can actually be seen in-game and not through postgame stats or Riot's API. I also create diffs for stats that can be directly compared between blue and red team to make the features more consolidated/simplified. There also only needs to be a single featue for the first kill, first tower, and first dragon since they are directly related between whoever gets it first/not. All matches are from the perspective of blue team.

# %%
# Start with lowercase column names
df.columns = df.columns.str.lower()

# Columns to drop completely
drop_cols = [
    'matchid',
    'gameduration',

    # jungle minions
    'bluetotaljungleminionskilled',
    'redtotaljungleminionskilled',

    # red vision stats
    'redwardsplaced',
    'redcontrolwardsplaced',
    'redwardsdestroyed',
    'redcontrolwardsdestroyed',

    # red first events (keeping only blue)
    'redfirstblood',
    'redfirstturret',
    'redfirstdragon',

    # experience is not visible in-game (optional)
    'bluetotalexperience',
    'redtotalexperience'
]

df = df.drop(columns=drop_cols, errors='ignore')

# Create diffs
df['kills_diff'] = df['bluekills'] - df['redkills']
df['deaths_diff'] = df['bluedeaths'] - df['reddeaths']
df['assists_diff'] = df['blueassists'] - df['redassists']
df['dragons_diff'] = df['bluedragons'] - df['reddragons']
df['heralds_diff'] = df['blueheralds'] - df['redheralds']
df['voidgrubs_diff'] = df['bluevoidgrubs'] - df['redvoidgrubs']
df['towers_diff'] = df['bluetowersdestroyed'] - df['redtowersdestroyed']
df['plates_diff'] = df['blueplatesdestroyed'] - df['redplatesdestroyed']
df['gold_diff'] = df['bluetotalgold'] - df['redtotalgold']
df['cs_diff'] = df['bluetotalminionskilled'] - df['redtotalminionskilled']

# Drop the original left/right stat columns
original_stats = [
    'bluekills', 'redkills',
    'bluedeaths', 'reddeaths',
    'blueassists', 'redassists',
    'bluedragons', 'reddragons',
    'blueheralds', 'redheralds',
    'bluevoidgrubs', 'redvoidgrubs',
    'bluetowersdestroyed', 'redtowersdestroyed',
    'blueplatesdestroyed', 'redplatesdestroyed',
    'bluetotalgold', 'redtotalgold',
    'bluetotalminionskilled', 'redtotalminionskilled'
]

df = df.drop(columns=original_stats, errors='ignore')

# Rename blue-side labels to generic names
df = df.rename(columns={
    'bluewins': 'win',
    'bluefirstblood': 'first_blood',
    'bluefirstturret': 'first_turret',
    'bluefirstdragon': 'first_dragon',
    'bluewardsplaced': 'wards_placed',
    'bluewardsdestroyed': 'wards_destroyed'
})

# Final ordering
df = df[
    [
        'win',
        'first_blood',
        'first_turret',
        'first_dragon',
        'wards_placed',
        'wards_destroyed',
        'kills_diff',
        'deaths_diff',
        'assists_diff',
        'dragons_diff',
        'heralds_diff',
        'voidgrubs_diff',
        'towers_diff',
        'plates_diff',
        'gold_diff',
        'cs_diff'
    ]
]

# %%
df.head()
# Out:
#    win  first_blood  first_turret  first_dragon  wards_placed  \
# 0    1            1             0             0            43
# 1    1            1             0             1            36
# 2    1            1             0             1            33
# 3    0            0             0             0            28
# 4    1            1             1             0            29
#
#    wards_destroyed  kills_diff  deaths_diff  assists_diff  dragons_diff  \
# 0               10          -3            3            -2            -1
# 1                5           3           -3             2             1
# 2                6          -4            4           -13             0
# 3                8          -9            9           -18             0
# 4                6           1           -1             0            -1
#
#    heralds_diff  voidgrubs_diff  towers_diff  plates_diff  gold_diff  cs_diff
# 0             0              -2           -1            7      -2610       -2
# ...

# %% [markdown]
# ### Splitting the Dataset

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.win.values
y_val = df_val.win.values
y_test = df_test.win.values

del df_train['win']
del df_val['win']
del df_test['win']

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Basic Data Checks

# %%
df_full_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75484 entries, 39062 to 77708
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   win              75484 non-null  int64
#  1   first_blood      75484 non-null  int64
#  2   first_turret     75484 non-null  int64
#  3   first_dragon     75484 non-null  int64
#  4   wards_placed     75484 non-null  int64
#  5   wards_destroyed  75484 non-null  int64
#  6   kills_diff       75484 non-null  int64
#  7   deaths_diff      75484 non-null  int64
#  8   assists_diff     75484 non-null  int64
#  9   dragons_diff     75484 non-null  int64
#  10  heralds_diff     75484 non-null  int64
#  11  voidgrubs_diff   75484 non-null  int64
#  12  towers_diff      75484 non-null  int64
#  13  plates_diff      75484 non-null  int64
#  14  gold_diff        75484 non-null  int64
#  15  cs_diff          75484 non-null  int64
# dtypes: int64(16)
# memory usage: 9.8 MB

# %%
df_full_train.describe().round()
# Out:
#            win  first_blood  first_turret  first_dragon  wards_placed  \
# count  75484.0      75484.0       75484.0       75484.0       75484.0
# mean       0.0          0.0           1.0           0.0          48.0
# std        0.0          0.0           0.0           0.0          39.0
# min        0.0          0.0           0.0           0.0           9.0
# 25%        0.0          0.0           0.0           0.0          30.0
# 50%        0.0          0.0           1.0           0.0          35.0
# 75%        1.0          1.0           1.0           1.0          48.0
# max        1.0          1.0           1.0           1.0         521.0
#
#        wards_destroyed  kills_diff  deaths_diff  assists_diff  dragons_diff  \
# count          75484.0     75484.0      75484.0       75484.0       75484.0
# mean              10.0        -0.0          0.0          -0.0          -0.0
# std                4.0         7.0          7.0          10.0           1.0
# ...

# %%
# Check for null values
df_full_train.isna().sum().sort_values(ascending=False)
# Out:
# win                0
# first_blood        0
# first_turret       0
# first_dragon       0
# wards_placed       0
# wards_destroyed    0
# kills_diff         0
# deaths_diff        0
# assists_diff       0
# dragons_diff       0
# heralds_diff       0
# voidgrubs_diff     0
# towers_diff        0
# plates_diff        0
# gold_diff          0
# cs_diff            0
# dtype: int64

# %%
numerical = [col for col in df_full_train.columns if df_full_train[col].dtype != 'object' and col not in ['win']]

# %%
df_full_train[numerical].var()
# Out:
# first_blood        2.499654e-01
# first_turret       2.496504e-01
# first_dragon       2.338319e-01
# wards_placed       1.556927e+03
# wards_destroyed    1.624399e+01
# kills_diff         4.768287e+01
# deaths_diff        4.768287e+01
# assists_diff       9.677872e+01
# dragons_diff       1.659494e+00
# heralds_diff       2.871384e-01
# voidgrubs_diff     1.536517e+01
# towers_diff        2.113025e+00
# plates_diff        2.007911e+01
# gold_diff          1.874402e+07
# cs_diff            1.657566e+03
# dtype: float64

# %% [markdown]
# ### Distribution Analysis

# %%
df_full_train[numerical].hist(figsize=(20,15), bins=15)
plt.suptitle("Distributions of Key Numerical Features")
# Out:
# Text(0.5, 0.98, 'Distributions of Key Numerical Features')

# %% [markdown]
# ### Target Variable Analysis

# %%
df_full_train.win.value_counts(normalize=True)
# Out:
# win
# 0    0.536736
# 1    0.463264
# Name: proportion, dtype: float64

# %%
global_win = df_full_train.win.mean()
global_win
# Out:
# np.float64(0.46326373801070425)

# %%
df_full_train['win'].value_counts(normalize=True).plot(kind='bar', color=['salmon', 'skyblue'])
plt.title("Target Distribution: Blue Team Win vs Loss")
plt.xticks([0, 1], ['Blue Loss', 'Blue Win'], rotation=0)
plt.ylabel("Proportion")
# Out:
# Text(0, 0.5, 'Proportion')

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# #### Correlation

# %%
# Compute correlation matrix
corr = df_full_train[numerical].corr()  # numerical is your list of numeric columns

# Plot heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %%
corr['win'].sort_values(ascending=False)
# Out:
# win                1.000000
# gold_diff          0.598841
# kills_diff         0.555051
# assists_diff       0.462617
# cs_diff            0.396414
# towers_diff        0.388225
# plates_diff        0.378518
# dragons_diff       0.297094
# first_turret       0.293012
# first_dragon       0.215556
# voidgrubs_diff     0.208742
# heralds_diff       0.177566
# first_blood        0.168818
# wards_destroyed    0.089529
# wards_placed       0.015011
# deaths_diff       -0.555051
# Name: win, dtype: float64

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Functions

# %% [markdown]
# The functions utilize DictVectorizer based on the templates in the course, though in practice it is not necessary since this dataset contains only numerical data. For the sake of simplicity this has not been modified, and may also be useful for future expansion if this project were to include categorical data.

# %%
# Train using numerical features with optional scaling
def train(df_train, y_train, C=1.0):
    # Convert numerical features to dicts for DictVectorizer
    dicts = df_train[numerical].to_dict(orient='records')
    dv = DictVectorizer(sparse=False)
    X_train = dv.fit_transform(dicts)
    
    # Scale numeric columns (assume first len(numerical) columns are numeric)
    scaler = StandardScaler()
    X_train[:, :len(numerical)] = scaler.fit_transform(X_train[:, :len(numerical)])
    
    # Train logistic regression
    model = LogisticRegression(solver='liblinear', C=C, max_iter=1000)
    model.fit(X_train, y_train)
    
    return dv, scaler, model

# %%
# Makes a prediction for df based on the given model
def predict(df, dv, scaler, model):
    X = dv.transform(df[numerical].to_dict(orient='records'))
    X[:, :len(numerical)] = scaler.transform(X[:, :len(numerical)])
    y_pred = model.predict_proba(X)[:, 1]
    return y_pred

# %%
# Cross validation function using k folds
def cross_validation(df, n=5, C=1.0):
    kfold = KFold(n_splits=n, shuffle=True, random_state=1)
    scores = []

    for train_idx, val_idx in kfold.split(df):
        df_train = df.iloc[train_idx]
        df_val = df.iloc[val_idx]

        y_train = df_train.win.values
        y_val = df_val.win.values

        dv, scaler, model = train(df_train, y_train, C=C)
        y_pred = predict(df_val, dv, scaler, model)

        auc = roc_auc_score(y_val, y_pred)
        scores.append(auc)

    return scores

# %% [markdown]
# #### Untuned Model

# %%
dv, scaler, model = train(df_train, y_train)
y_pred = predict(df_val, dv, scaler, model)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# 0.8655074985301099

# %% [markdown]
# #### Confusion Table and ROC Curve

# %%
# Evaluate model on all thresholds
scores = []

thresholds = np.linspace(0, 1, 101)

for t in thresholds:
    actual_positive = (y_val == 1)
    actual_negative = (y_val == 0)
    
    predict_positive = (y_pred >= t)
    predict_negative = (y_pred < t)

    tp = (predict_positive & actual_positive).sum()
    tn = (predict_negative & actual_negative).sum()

    fp = (predict_positive & actual_negative).sum()
    fn = (predict_negative & actual_positive).sum()
    
    scores.append((t, tp, fp, fn, tn))

# %%
# Create a Confusion Table and evaluate precision and recall
columns = ['threshold', 'tp', 'fp', 'fn', 'tn']
df_scores = pd.DataFrame(scores, columns=columns)

df_scores['p'] = df_scores.tp / (df_scores.tp + df_scores.fp)
df_scores['r'] = df_scores.tp / (df_scores.tp + df_scores.fn)

# %%
df_scores[::10]
# Out:
#      threshold    tp     fp    fn     tn         p         r
# 0          0.0  8683  10188     0      0  0.460124  1.000000
# 10         0.1  8557   7221   126   2967  0.542337  0.985489
# 20         0.2  8184   5225   499   4963  0.610336  0.942531
# 30         0.3  7716   3876   967   6312  0.665631  0.888633
# 40         0.4  7161   2792  1522   7396  0.719482  0.824715
# 50         0.5  6513   1977  2170   8211  0.767138  0.750086
# 60         0.6  5713   1258  2970   8930  0.819538  0.657952
# 70         0.7  4814    742  3869   9446  0.866451  0.554417
# 80         0.8  3637    346  5046   9842  0.913131  0.418864
# 90         0.9  2073     86  6610  10102  0.960167  0.238742
# 100        1.0     0      0  8683  10188       NaN  0.000000

# %%
plt.plot(df_scores.threshold, df_scores['p'], label='Precision')
plt.plot(df_scores.threshold, df_scores['r'], label='Recall')

plt.vlines(0.485, 0, 1, color='grey', linestyle='--', alpha=0.5)

plt.legend()
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_val, y_pred)

# %%
plt.figure(figsize=(5, 5))

plt.plot(fpr, tpr, label='Model')
plt.plot([0, 1], [0, 1], label='Random', linestyle='--')

plt.xlabel('FPR')
plt.ylabel('TPR')

plt.legend()

# %% [markdown]
# A good curve that performs better than the random model.

# %% [markdown]
# #### Cross Validation

# %%
n_splits = 5

for C in tqdm([0.001, 0.01, 0.1, 0.5, 1, 5, 10]):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=1)

    scores = cross_validation(df_full_train, n_splits, C)

    print('C: %s  Score: %.4f +- %.4f' % (C, np.mean(scores), np.std(scores)))
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# C: 0.001  Score: 0.8615 +- 0.0023
# C: 0.01  Score: 0.8633 +- 0.0023
# C: 0.1  Score: 0.8634 +- 0.0023
# C: 0.5  Score: 0.8634 +- 0.0023
# C: 1  Score: 0.8634 +- 0.0023
# C: 5  Score: 0.8634 +- 0.0023
# C: 10  Score: 0.8634 +- 0.0023

# %% [markdown]
# There are several ties so we will stick with C = 0.1 for stronger regularization.

# %% [markdown]
# ### Decision Tree

# %%
# Convert dataframes into dicts
train_dicts = df_train.to_dict(orient='records')
val_dicts = df_val.to_dict(orient='records')
test_dicts = df_test.to_dict(orient='records')

# Convert dicts into matrices
dv = DictVectorizer(sparse=True)
X_train = dv.fit_transform(train_dicts)
X_val = dv.transform(val_dicts)
X_test = dv.transform(test_dicts)

# %% [markdown]
# #### Parameter Tuning

# %%
scores = []

for depth in tqdm([4, 5, 6, 7, 8, 9, 10], desc="Outer Loop"):
    for s in tqdm([1, 5, 10, 15, 20, 500, 100, 200], desc="Inner Loop", leave=False):
        dt = DecisionTreeClassifier(max_depth=depth, min_samples_leaf=s)
        dt.fit(X_train, y_train)

        y_pred = dt.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)
        
        scores.append((depth, s, auc))
# Out:
# ...
# Inner Loop:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
columns = ['max_depth', 'min_samples_leaf', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
df_scores_pivot = df_scores.pivot(index='min_samples_leaf', columns=['max_depth'], values=['auc'])
df_scores_pivot.round(3)
# Out:
#                     auc
# max_depth            4      5      6      7      8      9      10
# min_samples_leaf
# 1                 0.859  0.861  0.861  0.859  0.856  0.852  0.843
# 5                 0.859  0.861  0.861  0.859  0.857  0.852  0.844
# 10                0.859  0.861  0.861  0.860  0.858  0.855  0.848
# 15                0.859  0.861  0.861  0.860  0.859  0.855  0.849
# 20                0.859  0.861  0.861  0.860  0.858  0.855  0.849
# 100               0.859  0.861  0.862  0.862  0.860  0.859  0.858
# 200               0.859  0.861  0.862  0.862  0.862  0.861  0.861
# 500               0.859  0.861  0.862  0.862  0.862  0.862  0.862

# %%
sns.heatmap(df_scores_pivot, annot=True, fmt=".3f")
# Out:
# <Axes: xlabel='None-max_depth', ylabel='min_samples_leaf'>

# %% [markdown]
# There are multiple ties but we are trying to go for the min best value so **max_depth = 6** and **min_samples_leaf = 100** are the best parameters.

# %% [markdown]
# ### Random Forest

# %% [markdown]
# #### Finding best n_estimator

# %%
scores = []

for n in tqdm([10, 50, 100, 150, 200]):
    rf = RandomForestClassifier(n_estimators=n, random_state=1, n_jobs=-1)
    rf.fit(X_train, y_train)

    y_pred = rf.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_pred)
    
    scores.append((n, auc))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
df_scores = pd.DataFrame(scores, columns=['n_estimators', 'auc'])

# %%
plt.plot(df_scores.n_estimators, df_scores.auc)

# %% [markdown]
# The auc appears to improve with higher n_estimators so will cap it at **n_estimators=200**

# %% [markdown]
# #### Finding best max_depth

# %%
scores = []

for d in tqdm([1, 5, 10, 15], desc='Outer Loop'):
    for n in tqdm([10, 50, 100, 150, 200], desc='Inner Loop', leave=False):
        rf = RandomForestClassifier(n_estimators=n,
                                    max_depth=d,
                                    random_state=1,
                                    n_jobs=-1)
        rf.fit(X_train, y_train)

        y_pred = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)

        scores.append((d, n, auc))
# Out:
# ...
# Inner Loop:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
columns = ['max_depth', 'n_estimators', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
for d in [1, 5, 10, 15]:
    df_subset = df_scores[df_scores.max_depth == d]
    
    plt.plot(df_subset.n_estimators, df_subset.auc,
             label='max_depth=%d' % d)

plt.legend()

# %% [markdown]
# The best depth appears to be **max_depth=10**.

# %% [markdown]
# #### Finding best min_samples_leaf

# %%
scores = []

for s in tqdm([1, 5, 10, 20, 50, 100], desc='Outer Loop'):
    for n in tqdm([1, 50, 100, 150, 200], desc='Inner Loop', leave=False):
        rf = RandomForestClassifier(n_estimators=n,
                                    max_depth=10,
                                    min_samples_leaf=s,
                                    random_state=1,
                                    n_jobs=-1)
        rf.fit(X_train, y_train)

        y_pred = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)

        scores.append((s, n, auc))
# Out:
# ...
# Inner Loop:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
columns = ['min_samples_leaf', 'n_estimators', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
colors = ['black', 'blue', 'orange', 'red', 'grey', 'green']
values = [1, 5, 10, 20, 50, 100]

for s, col in zip(values, colors):
    df_subset = df_scores[df_scores.min_samples_leaf == s]
    
    plt.plot(df_subset.n_estimators, df_subset.auc,
             color=col,
             label='min_samples_leaf=%d' % s)

plt.legend()

# %% [markdown]
# **min_sample_leaf=50** and 100 appear to be very close but for our purposes I will opt for 50 as the best one.

# %% [markdown]
# ### XGBoost

# %% [markdown]
# #### Set-Up

# %%
features = list(dv.get_feature_names_out())
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)

# %%
watchlist = [(dtrain, "train"), (dval, "val")]

# %%
scores = {} # dictionary to store results for each eta

# %% [markdown]
# #### Functions

# %%
def plot_group(prefix, scores):
    plt.figure(figsize=(10, 6))

    # Get all keys that START with the prefix + "="
    matching = {k: v for k, v in scores.items() if k.startswith(prefix + "=")}

    if not matching:
        print(f"No matching keys for prefix '{prefix}'")
        return

    for key, df in matching.items():
        plt.plot(df['iter'], df['val_auc'], label=key)

    plt.xlabel("Iteration")
    plt.ylabel("Validation AUC")
    plt.title(f"AUC vs Iterations for {prefix}")
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# #### Parameter Tuning

# %%
# Train XGBoost models for each eta and store AUC results
etas = [0.01, 0.05, 0.1, 0.3] # list of parameter values. in this case it is 'eta'.

for eta in tqdm(etas):
    evals_result = {}

    xgb_params = {
        'eta': eta,
        'max_depth': 6,
        'min_child_weight': 1,

        'subsample': 0.8,
        'colsample_bytree': 0.8,

        'reg_lambda': 1.0,
        'reg_alpha': 0.0,

        'objective': 'binary:logistic',
        'eval_metric': 'auc',

        'nthread': 8,
        'seed': 1,
        'verbosity': 1
    }

    model = xgb.train(
        xgb_params,
        dtrain,
        evals=watchlist,
        verbose_eval=0,
        num_boost_round=200,
        evals_result=evals_result
    )

    columns = ['iter', 'train_auc', 'val_auc']
    train_aucs = list(evals_result['train'].values())[0]
    val_aucs = list(evals_result['val'].values())[0]

    df_results = pd.DataFrame(
        list(zip(range(1, len(train_aucs) + 1), train_aucs, val_aucs)),
        columns=columns
    )

    key = f'eta={eta}'
    scores[key] = df_results
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plot_group("eta", scores)

# %% [markdown]
# **eta=0.05** starts stronger than **eta=0.01** before being overtaken and also starts lower than eta=0.1. It is overall the strongest when considering on average.

# %%
eta = 0.05

# %%
# Train XGBoost models for each max_depth and store AUC results
max_depths = [3, 5, 10, 15]

for max_depth in tqdm(max_depths):
    evals_result = {}

    xgb_params = {
        'eta': eta,
        'max_depth': max_depth,
        'min_child_weight': 1,

        'subsample': 0.8,
        'colsample_bytree': 0.8,

        'reg_lambda': 1.0,
        'reg_alpha': 0.0,

        'objective': 'binary:logistic',
        'eval_metric': 'auc',

        'nthread': 8,
        'seed': 1,
        'verbosity': 1
    }

    model = xgb.train(
        xgb_params,
        dtrain,
        evals=watchlist,
        verbose_eval=0,
        num_boost_round=200,
        evals_result=evals_result
    )

    columns = ['iter', 'train_auc', 'val_auc']
    train_aucs = list(evals_result['train'].values())[0]
    val_aucs = list(evals_result['val'].values())[0]

    df_results = pd.DataFrame(
        list(zip(range(1, len(train_aucs) + 1), train_aucs, val_aucs)),
        columns=columns
    )

    key = f'max_depth={max_depth}'
    scores[key] = df_results
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plot_group("max_depth", scores)

# %% [markdown]
# **max_depth=5** has a stronger start than max_depth=3 even though 3 surpasses it eventually so we will stick with it as our top depth.

# %%
max_depth = 5

# %%
# Train XGBoost models for each min_child_weight and store AUC results
min_child_weights = [1, 10, 30, 50]

for min_child_weight in tqdm(min_child_weights):
    evals_result = {}

    xgb_params = {
        'eta': eta,
        'max_depth': max_depth,
        'min_child_weight': min_child_weight,

        'subsample': 0.8,
        'colsample_bytree': 0.8,

        'reg_lambda': 1.0,
        'reg_alpha': 0.0,

        'objective': 'binary:logistic',
        'eval_metric': 'auc',

        'nthread': 8,
        'seed': 1,
        'verbosity': 1
    }

    model = xgb.train(
        xgb_params,
        dtrain,
        evals=watchlist,
        verbose_eval=0,
        num_boost_round=200,
        evals_result=evals_result
    )

    columns = ['iter', 'train_auc', 'val_auc']
    train_aucs = list(evals_result['train'].values())[0]
    val_aucs = list(evals_result['val'].values())[0]

    df_results = pd.DataFrame(
        list(zip(range(1, len(train_aucs) + 1), train_aucs, val_aucs)),
        columns=columns
    )

    key = f'min_child_weight={min_child_weight}'
    scores[key] = df_results
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plot_group("min_child_weight", scores)

# %% [markdown]
# The weights are close until the end where **min_child_weight=30** comes out on top.

# %%
min_child_weight = 30

# %%
# Train XGBoost models for each subsample and store AUC results
subsamples = [0.1, 0.5, 0.8, 1.0]

for subsample in tqdm(subsamples):
    evals_result = {}

    xgb_params = {
        'eta': eta,
        'max_depth': max_depth,
        'min_child_weight': min_child_weight,

        'subsample': subsample,
        'colsample_bytree': 0.8,

        'reg_lambda': 1.0,
        'reg_alpha': 0.0,

        'objective': 'binary:logistic',
        'eval_metric': 'auc',

        'nthread': 8,
        'seed': 1,
        'verbosity': 1
    }

    model = xgb.train(
        xgb_params,
        dtrain,
        evals=watchlist,
        verbose_eval=0,
        num_boost_round=200,
        evals_result=evals_result
    )

    columns = ['iter', 'train_auc', 'val_auc']
    train_aucs = list(evals_result['train'].values())[0]
    val_aucs = list(evals_result['val'].values())[0]

    df_results = pd.DataFrame(
        list(zip(range(1, len(train_aucs) + 1), train_aucs, val_aucs)),
        columns=columns
    )

    key = f'subsample={subsample}'
    scores[key] = df_results
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plot_group("subsample", scores)

# %% [markdown]
# **subsample = 0.8** is a clear winner.

# %%
subsample = 0.8

# %%
# Train XGBoost models for each colsample_bytree and store AUC results
colsample_bytrees = [0.1, 0.5, 0.8, 1.0]

for colsample_bytree in tqdm(colsample_bytrees):
    evals_result = {}

    xgb_params = {
        'eta': eta,
        'max_depth': max_depth,
        'min_child_weight': min_child_weight,

        'subsample': subsample,
        'colsample_bytree': colsample_bytree,

        'reg_lambda': 1.0,
        'reg_alpha': 0.0,

        'objective': 'binary:logistic',
        'eval_metric': 'auc',

        'nthread': 8,
        'seed': 1,
        'verbosity': 1
    }

    model = xgb.train(
        xgb_params,
        dtrain,
        evals=watchlist,
        verbose_eval=0,
        num_boost_round=200,
        evals_result=evals_result
    )

    columns = ['iter', 'train_auc', 'val_auc']
    train_aucs = list(evals_result['train'].values())[0]
    val_aucs = list(evals_result['val'].values())[0]

    df_results = pd.DataFrame(
        list(zip(range(1, len(train_aucs) + 1), train_aucs, val_aucs)),
        columns=columns
    )

    key = f'colsample_bytree={colsample_bytree}'
    scores[key] = df_results
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plot_group("colsample_bytree", scores)

# %% [markdown]
# **colsample_bytree = 0.8** appears to be the strongest value overall.

# %%
colsample_bytree = 0.8

# %%
# Train XGBoost models for each reg_lambda and store AUC results
reg_lambdas = [0.1, 1, 5, 10, 20]

for reg_lambda in tqdm(reg_lambdas):
    evals_result = {}

    xgb_params = {
        'eta': eta,
        'max_depth': max_depth,
        'min_child_weight': min_child_weight,

        'subsample': subsample,
        'colsample_bytree': colsample_bytree,

        'reg_lambda': reg_lambda,
        'reg_alpha': 0.0,

        'objective': 'binary:logistic',
        'eval_metric': 'auc',

        'nthread': 8,
        'seed': 1,
        'verbosity': 1
    }

    model = xgb.train(
        xgb_params,
        dtrain,
        evals=watchlist,
        verbose_eval=0,
        num_boost_round=200,
        evals_result=evals_result
    )

    columns = ['iter', 'train_auc', 'val_auc']
    train_aucs = list(evals_result['train'].values())[0]
    val_aucs = list(evals_result['val'].values())[0]

    df_results = pd.DataFrame(
        list(zip(range(1, len(train_aucs) + 1), train_aucs, val_aucs)),
        columns=columns
    )

    key = f'reg_lambda={reg_lambda}'
    scores[key] = df_results
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
plot_group("reg_lambda", scores)

# %% [markdown]
# Scores are quite close with **reg_lambda = 20** rising highest.

# %%
reg_lambda = 20

# %%
# Train XGBoost models for each reg_alpha and store AUC results
reg_alphas = [0, 0.1, 1, 5, 10]

for reg_alpha in tqdm(reg_alphas):
    evals_result = {}

    xgb_params = {
        'eta': eta,
        'max_depth': max_depth,
        'min_child_weight': min_child_weight,

        'subsample': subsample,
        'colsample_bytree': colsample_bytree,

        'reg_lambda': reg_lambda,
        'reg_alpha': reg_alpha,

        'objective': 'binary:logistic',
        'eval_metric': 'auc',

        'nthread': 8,
        'seed': 1,
        'verbosity': 1
    }

    model = xgb.train(
        xgb_params,
        dtrain,
        evals=watchlist,
        verbose_eval=0,
        num_boost_round=200,
        evals_result=evals_result
    )

    columns = ['iter', 'train_auc', 'val_auc']
    train_aucs = list(evals_result['train'].values())[0]
    val_aucs = list(evals_result['val'].values())[0]

    df_results = pd.DataFrame(
        list(zip(range(1, len(train_aucs) + 1), train_aucs, val_aucs)),
        columns=columns
    )

    key = f'reg_alpha={reg_alpha}'
    scores[key] = df_results
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
plot_group("reg_alpha", scores)

# %% [markdown]
# There isn't a clear differentiator but **reg_alpha = 0.1** appears to stand out overall highest by the end, especially compared to reg_alpha=1 which was neck-and-neck before dropping.

# %% [markdown]
# ### Selecting Final Model

# %%
# Tuned Logistic Regression
dv, scaler, model = train(df_train, y_train, C=0.1)
y_pred = predict(df_val, dv, scaler, model)
roc_auc_score(y_val, y_pred)
# Out:
# 0.8655320626375924

# %%
# Tuned Decision Tree
dt = DecisionTreeClassifier(max_depth=6, min_samples_leaf=100)
dt.fit(X_train, y_train)

y_pred = dt.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# 0.8618535112385143

# %%
# Tuned Random Forest
rf = RandomForestClassifier(n_estimators=200,
                            max_depth=10,
                            min_samples_leaf=50,
                            random_state=1)
rf.fit(X_train, y_train)

y_pred = rf.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# 0.8642523890714071

# %%
# Tuned XGB
xgb_params = {
    'eta': 0.05, 
    'max_depth': 5,
    'min_child_weight': 30,

    'subsample': 0.8,
    'colsample_bytree': 0.8,

    'reg_lambda': 20,
    'reg_alpha': 0.1,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=200)
y_pred = model.predict(dval)
roc_auc_score(y_val, y_pred)
# Out:
# 0.8651956937548294

# %% [markdown]
# We can conclude that **logistic regression** provides the strongest model by a small margin.

# %% [markdown]
# ### Evaluating Final Model

# %%
# Prepare full training dataset for evaluating test dataset
df_full_train = df_full_train.reset_index(drop=True)
y_full_train = df_full_train.win.values
del df_full_train['win']

# %%
dv, scaler, model = train(df_full_train, y_full_train, C=0.1)
y_pred = predict(df_val, dv, scaler, model)
roc_auc_score(y_val, y_pred)
# Out:
# 0.865677853385038
